# %%
import pandas as pd
import numpy as np
import time
from random import randrange, getrandbits
from math import gcd
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\MTECH\\SEM 3\\Big Data\\Big Dtata Project\OnlineNewsPopularity\\OnlineNewsPopularity.csv')
data.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
data.columns.unique()
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
text=list(data[' n_tokens_content'])
text
# Out:
# [219.0,
#  255.0,
#  211.0,
#  531.0,
#  1072.0,
#  370.0,
#  960.0,
#  989.0,
#  97.0,
#  231.0,
#  1248.0,
#  187.0,
#  274.0,
#  285.0,
#  259.0,
#  682.0,
#  1118.0,
#  397.0,
#  103.0,
#  1207.0,
#  1248.0,
#  391.0,
#  1154.0,
#  125.0,
#  244.0,
#  266.0,
#  331.0,
#  1225.0,
#  243.0,
#  723.0,
#  708.0,
#  633.0,
#  290.0,
#  597.0,
#  204.0,
#  315.0,
#  1244.0,
#  257.0,
#  799.0,
#  194.0,
#  1036.0,
#  174.0,
#  1237.0,
#  1081.0,
#  1022.0,
#  142.0,
#  1190.0,
#  161.0,
#  1108.0,
#  1089.0,
#  214.0,
#  944.0,
#  1030.0,
#  454.0,
#  1115.0,
#  555.0,
#  474.0,
#  130.0,
#  444.0,
#  280.0,
#  1024.0,
#  238.0,
#  1070.0,
#  463.0,
#  1005.0,
#  403.0,
#  251.0,
#  317.0,
#  177.0,
#  109.0,
#  399.0,
#  460.0,
#  443.0,
#  218.0,
#  988.0,
#  374.0,
#  356.0,
#  1226.0,
#  1121.0,
#  288.0,
#  414.0,
#  134.0,
#  281.0,
#  499.0,
#  268.0,
#  925.0,
#  261.0,
#  306.0,
#  909.0,
#  999.0,
#  1011.0,
#  413.0,
#  180.0,
#  759.0,
#  1226.0,
#  241.0,
#  168.0,
# ...

# %%
p=131
q=197
n=p*q
t=(p-1)*(q-1)

# %%
for i in range(2,t,1):
    if gcd(i,t)==1:
        e=i
        break
for i in range(1,10): 
    x = 1 + i*t
    if x % e == 0: 
        d = int(x/e) 
        break

# %%
S=[]
for i in range(0,len(text),1):
    if i in text:
        S.append((int(text[i])**d) % n)
    else:
        S.append(text[i])

# %%
M1=[]
for i in range(0,len(S),1):
    if i in text:
        M1.append((int(S[i])**e) % n)
    else:
        M1.append(S[i])

# %%
M1
# Out:
# [219,
#  255.0,
#  211.0,
#  531.0,
#  1072.0,
#  370.0,
#  960.0,
#  989.0,
#  97.0,
#  231.0,
#  1248.0,
#  187.0,
#  274.0,
#  285.0,
#  259.0,
#  682.0,
#  1118.0,
#  397.0,
#  103,
#  1207.0,
#  1248.0,
#  391,
#  1154,
#  125.0,
#  244,
#  266,
#  331,
#  1225,
#  243,
#  723,
#  708,
#  633,
#  290,
#  597.0,
#  204,
#  315,
#  1244.0,
#  257,
#  799,
#  194,
#  1036,
#  174,
#  1237,
#  1081,
#  1022,
#  142,
#  1190,
#  161,
#  1108,
#  1089,
#  214,
#  944,
#  1030,
#  454,
#  1115,
#  555,
#  474,
#  130,
#  444,
#  280,
#  1024,
#  238,
#  1070,
#  463,
#  1005,
#  403,
#  251,
#  317,
#  177,
#  109,
#  399,
#  460,
#  443,
#  218,
#  988,
#  374,
#  356,
#  1226,
#  1121,
#  288,
#  414,
#  134,
#  281,
#  499,
#  268,
#  925,
#  261,
#  306,
#  909,
#  999,
#  1011,
#  413,
#  180,
#  759,
#  1226,
#  241,
#  168,
#  1121,
#  1174,
#  376,
#  142,
#  825,
#  883,
#  1125,
#  498,
#  540,
#  855,
#  223,
#  349,
#  1007,
#  464,
#  233,
#  167,
#  825,
#  1099,
#  263,
# ...
